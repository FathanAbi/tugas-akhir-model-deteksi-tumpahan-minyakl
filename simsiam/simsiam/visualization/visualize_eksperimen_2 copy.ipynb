# %%
import os
import numpy as np
from HSI_class import HSI
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# Load prediction
results_LR = []
results_LR_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626"

results_RF = []
results_RF_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756"

results_SVM = []
results_SVM_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701"

results_OneDCNN = []
results_OneDCNN_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242"

results_TwoDCNN = []
results_TwoDCNN_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445"

results_HybridSN = []
results_HybridSN_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303"

results_512 = []
results_512_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253"


total = 0
for filename in os.listdir(results_LR_path):
    file_path = os.path.join(results_LR_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_LR.append(pred_matrix)
        total +=1

for filename in os.listdir(results_RF_path):
    file_path = os.path.join(results_RF_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_RF.append(pred_matrix)
        total +=1

for filename in os.listdir(results_SVM_path):
    file_path = os.path.join(results_SVM_path, filename)         
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_SVM.append(pred_matrix)
        total +=1

for filename in os.listdir(results_OneDCNN_path):
    file_path = os.path.join(results_OneDCNN_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_OneDCNN.append(pred_matrix)
        total +=1

for filename in os.listdir(results_TwoDCNN_path):
    file_path = os.path.join(results_TwoDCNN_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_TwoDCNN.append(pred_matrix)
        total +=1

for filename in os.listdir(results_HybridSN_path):
    file_path = os.path.join(results_HybridSN_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_HybridSN.append(pred_matrix)
        total +=1

for filename in os.listdir(results_512_path):
    file_path = os.path.join(results_512_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        pred_matrix = np.load(file_path)
        results_512.append(pred_matrix)
        total +=1
# Out:
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 0 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 1 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 2 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 3 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 4 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 5 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 6 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 7 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 8 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\LR\predictions\LR_REV\20250617_191626\results 9 LR.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 0 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 1 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 2 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 3 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 4 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 5 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 6 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 7 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 8 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\RF\predictions\RF_REV\20250617_130756\results 9 RF.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 0 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 1 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 2 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 3 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 4 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 5 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 6 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 7 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 8 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\SVM\predictions\SVM_REV\20250616_220701\results 9 SVM.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 0 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 1 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 2 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 3 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 4 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 5 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 6 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 7 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 8 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\1DCNN\predictions\OneDCNN_REV\20250617_160242\results 9 1DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 0 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 1 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 2 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 3 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 4 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 5 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 6 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 7 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 8 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\2DCNN\predictions\TwoDCNN_REV\20250617_152445\results 9 2DCNN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 0 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 1 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 2 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 3 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 4 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 5 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 6 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 7 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 8 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\HybridSN\predictions\HybridSN_REV\20250617_181303\results 9 HybridSN.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 0 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 1 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 2 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 3 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 4 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 5 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 6 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 7 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 8 MyMethod.npy
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\simsiam\simsiam\TESTING\new_mymethod\predictions\MyMethod_512\20250618_160253\results 9 MyMethod.npy

# %%
dataset_path = r"C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets"

datasets = []
dataset_used = 1

max = 9
i = 0
for filename in os.listdir(dataset_path):
    if i > max:
        break
    file_path = os.path.join(dataset_path, filename)
    if os.path.isfile(file_path):  # Check if it's a file
        print(f"Processing file: {file_path}")
        hsi = HSI(file_path)
        datasets.append(hsi)
    i += 1
# Out:
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM01.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM02.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM03.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM04.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM05.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM06.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM07.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM08.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM09.mat
# Processing file: C:\Users\PC\Documents\code\TA\tugas-akhir-model-deteksi-tumpahan-minyakl\Hyperspectral oil spill detection datasets\GM10.mat

# %%
print(total)
# Define custom color map for prediction
custom_cmap = ListedColormap(['white', 'black'])

# Create figure with 2 subplots side by side
fig, axs = plt.subplots(1, 4, figsize=(12, 40))

i  = 0
j = 4
print(i)
dataset = datasets[j]
gt = dataset.gt

# --- First plot: Ground Truth (Binary Mask) ---
im1 = axs[0].imshow(1 - gt, cmap='gray')
axs[0].set_title(f'(Ground Truth) {i+1}')
axs[0].axis('off')
# fig.colorbar(im1, ax=axs[i][0], fraction=0.046, pad=0.04)

# --- Second plot: Predictions ---
im2 = axs[1].imshow(results_LR[j], cmap=custom_cmap, interpolation='nearest')
axs[1].set_title(f'LR {j+1}')
axs[1].axis('off')
# fig.colorbar(im2, ax=axs[i][1], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Third plot: Predictions ---
im2 = axs[2].imshow(results_RF[j], cmap=custom_cmap, interpolation='nearest')
axs[2].set_title(f'RF {j+1}')
axs[2].axis('off')
# fig.colorbar(im2, ax=axs[i][2], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Third plot: Predictions ---
im2 = axs[3].imshow(results_SVM[j], cmap=custom_cmap, interpolation='nearest')
axs[3].set_title(f'SVM {j+1}')
axs[3].axis('off')
# fig.colorbar(im2, ax=axs[i][2], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)



    





plt.tight_layout()
plt.show()
# Out:
# 70
# 0

# %%
fig, axs = plt.subplots(1, 4, figsize=(12, 40))

# --- Third plot: Predictions ---
im2 = axs[0].imshow(results_OneDCNN[j], cmap=custom_cmap, interpolation='nearest')
axs[0].set_title(f'1D CNN {j+1}')
axs[0].axis('off')
# fig.colorbar(im2, ax=axs[i][2], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Third plot: Predictions ---
im2 = axs[1].imshow(results_TwoDCNN[j], cmap=custom_cmap, interpolation='nearest')
axs[1].set_title(f'2D CNN {j+1}')
axs[1].axis('off')
# fig.colorbar(im2, ax=axs[i][2], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Third plot: Predictions ---
im2 = axs[2].imshow(results_HybridSN[j], cmap=custom_cmap, interpolation='nearest')
axs[2].set_title(f'HybridSN {j+1}')
axs[2].axis('off')
# fig.colorbar(im2, ax=axs[i][2], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)


# --- Second plot: Predictions ---
im2 = axs[3].imshow(results_512[j], cmap=custom_cmap, interpolation='nearest')
axs[3].set_title(f'MyModel_Medium {j+1}')
axs[3].axis('off')
# fig.colorbar(im2, ax=axs[i][3], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

plt.tight_layout()
plt.show()

# %%
print(total)
# Define custom color map for prediction
custom_cmap = ListedColormap(['white', 'black'])

# Create figure with 2 subplots side by side
fig, axs = plt.subplots(10, 5, figsize=(15, 50))

i = 0
j = 9
print(i)
dataset = datasets[i]
gt = dataset.gt

# --- First plot: Ground Truth (Binary Mask) ---
im1 = axs[i][0].imshow(1 - gt, cmap='gray')
axs[i][0].set_title(f'(Ground Truth) {i+1}')
axs[i][0].axis('off')
# fig.colorbar(im1, ax=axs[i][0], fraction=0.046, pad=0.04)

# --- Second plot: Predictions ---
im2 = axs[i][1].imshow(results_full[i], cmap=custom_cmap, interpolation='nearest')
axs[i][1].set_title(f'MyModel_Full {i+1}')
axs[i][1].axis('off')
# fig.colorbar(im2, ax=axs[i][1], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Third plot: Predictions ---
im2 = axs[i][2].imshow(results_1024[i], cmap=custom_cmap, interpolation='nearest')
axs[i][2].set_title(f'MyModel_Large {i+1}')
axs[i][2].axis('off')
# fig.colorbar(im2, ax=axs[i][2], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Second plot: Predictions ---
im2 = axs[i][3].imshow(results_512[i], cmap=custom_cmap, interpolation='nearest')
axs[i][3].set_title(f'MyModel_Medium {i+1}')
axs[i][3].axis('off')
# fig.colorbar(im2, ax=axs[i][3], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)

# --- Second plot: Predictions ---
im2 = axs[i][4].imshow(results_256[i], cmap=custom_cmap, interpolation='nearest')
axs[i][4].set_title(f'MyModel_Small {i+1}')
axs[i][4].axis('off')
# fig.colorbar(im2, ax=axs[i][4], ticks=[0, 1], label="Classes", fraction=0.046, pad=0.04)
im2.set_clim(-0.5, 1.5)





plt.tight_layout()
plt.show()
# Out:
# 70
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 20
#      16 axs[i][0].axis('off')
#      17 # fig.colorbar(im1, ax=axs[i][0], fraction=0.046, pad=0.04)
#      18
#      19 # --- Second plot: Predictions ---
# ---> 20 im2 = axs[i][1].imshow(results_full[i], cmap=custom_cmap, interpolation='nearest')
#      21 axs[i][1].set_title(f'MyModel_Full {i+1}')
#      22 axs[i][1].axis('off')
#
# NameError: name 'results_full' is not defined
